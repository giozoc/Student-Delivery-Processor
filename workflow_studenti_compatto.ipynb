# %% [markdown]
# # Esecuzione consegne studenti
#
# Metti questo notebook nella cartella root insieme a `studenti_compatto.py`, ai file Excel e alle cartelle degli studenti.

# %%
from studenti_compatto import process_root, EXCEL_FILES
EXCEL_FILES
# Out:
# ['AA2024-2025.xls', 'AA2025-2026.xls']

# %%
output = process_root(
    root='.',
    keep_originals=False,
    output_excel='studenti_compilati.xlsx'
)
output
# Out:
# Cartella non trovata negli Excel: __pycache__
# MuPDF error: format error: No common ancestor in structure tree
#
# Creato PDF: ALBANO_SARA.pdf
# Creato PDF: ALBANO_VALENTINA.pdf
# Cartella non trovata negli Excel: ANDREA AIELLO_513881_assignsubmission_file
# Creato PDF: BAGNALE_ALFONSO.pdf
# Creato PDF: BRUNO_VALENTINA.pdf
# Creato PDF: CAMPANA_FELICE.pdf
# Creato PDF: CARDELLA_ALESSANDRA.pdf
# Creato PDF: CASILLO_ANNA.pdf
# Creato PDF: COCOZZA_MATTEO.pdf
# Creato PDF: COSTABILE_GIADA.pdf
# Creato PDF: D'URSI_FRANCESCO.pdf
# Creato PDF: DE_LISA_ANNALISA.pdf
# Creato PDF: DE_LISIO_GRETA.pdf
# Creato PDF: DIDIO_FRANCESCA.pdf
# Creato PDF: ELEFANTE_ERIKA.pdf
# Creato PDF: ESPOSITO_IOLE.pdf
# Creato PDF: ESPOSITO_SABRINA.pdf
# Creato PDF: FORTUNATO_EMANUELE.pdf
# Creato PDF: GESUMMARIA_SIMONE.pdf
# Creato PDF: GIOIA_FRANCESCO.pdf
# Creato PDF: LONGOBARDI_GIUSEPPE_PIO.pdf
# Creato PDF: MOCCIA_ANTONIO.pdf
# Creato PDF: NEVOLA_CLAUDIA.pdf
# Creato PDF: OSTACOLO_ROSSELLA.pdf
# Creato PDF: PELUSO_DOMENICO.pdf
# Creato PDF: PUCCIARELLI_VALERIO.pdf
# Creato PDF: ROBUSTELLI_SIMONA.pdf
# Creato PDF: ROMANO_ALESSIA.pdf
# Creato PDF: ROSSI_ALESSANDRO.pdf
# Creato PDF: SCORZELLI_ENRICO.pdf
# Creato PDF: SERLUCA_SOFIA.pdf
# Creato PDF: SPAGNUOLO_MARIANTONIETTA.pdf
# Creato PDF: SPAGNUOLO_TERESA.pdf
# Creato PDF: STABILE_MARTINA.pdf
# Creato PDF: TAFURI_FRANCESCO.pdf
# Creato PDF: VISCIANI_GIUSEPPE_VINCENZO.pdf
# Creato PDF: VITALE_MARIKA.pdf
# Creato file Excel finale: /Users/zgiov/Downloads/Metodi e tecniche di campionamentoStatistica e data analysis, A.A. 20252026-Attività 5 (scadenza 20042026, ore 0900) ULTIMA ATTIVITA DEL CORSO-85433/studenti_compilati.xlsx
# PosixPath('/Users/zgiov/Downloads/Metodi e tecniche di campionamentoStatistica e data analysis, A.A. 20252026-Attività 5 (scadenza 20042026, ore 0900) ULTIMA ATTIVITA DEL CORSO-85433/studenti_compilati.xlsx')

# %% [markdown]
# Quando hai verificato che tutto è corretto, puoi rilanciare con `keep_originals=False`.
